# %% [markdown]
# <a href="https://colab.research.google.com/github/eentartetekunst/NGS_bioinformatics/blob/main/HW2_subread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  4. Оцените экспрессию генов в каждом образце при помощи Rsubread

# %% [markdown]
# https://subread.sourceforge.net/subread.html
# https://subread.sourceforge.net/featureCounts.html
#
# https://subread.sourceforge.net/RNAseqCaseStudy.html

# %%
! pip install -q condacolab

# %%
import condacolab
condacolab.install()

# %%
! conda install -c bioconda subread

# %% [markdown]
# # Mapping

# %%
! wget http://ftp.ensembl.org/pub/release-107/fasta/mus_musculus/dna/Mus_musculus.GRCm39.dna.chromosome.19.fa.gz #chr19 sequence
! wget http://ftp.ensembl.org/pub/release-107/gtf/mus_musculus/Mus_musculus.GRCm39.107.gtf.gz # annotation
! gzip -d Mus_musculus.GRCm39.dna.chromosome.19.fa.gz # unarchieve files

! touch chr19-annotation 
! gzip -d Mus_musculus.GRCm39.107.gtf.gz > chr19-annotation 

# select chr 19 from the annotation
! touch chr19-annotation 
! grep -P '^19\t' /content/Mus_musculus.GRCm39.107.gtf > chr19-annotation

# %% [markdown]
# # FEATURE COUNTS - count reads on features

# %%
# %%shell
# reads_list='C14_5 B34 B14_5 C15_5 C17_5 B17_5 C34 B20 B15_5 C20'
# #fcnames_list='C14_5 B34 B14_5 C15_5 C17_5 B17_5 C34 B20 B15_5 C20'
#
# for i in ${reads_list}
# do featureCounts -a /content/Mus_musculus.GRCm39.107.gtf -o ${i}_fc ${i}.s.bam
# done
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o C14_5.s.bam                                    ||
# ||                                                                            ||
# ||             Output file : C14_5_fc                                         ||
# ||                 Summary : C14_5_fc.summary                                 ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file C14_5.s.bam...                                            ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 367418                                               ||
# ||    Successfully assigned alignments : 281679 (76.7%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "C14_5_fc.summary"        ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o B34.s.bam                                      ||
# ||                                                                            ||
# ||             Output file : B34_fc                                           ||
# ||                 Summary : B34_fc.summary                                   ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file B34.s.bam...                                              ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 411115                                               ||
# ||    Successfully assigned alignments : 329367 (80.1%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "B34_fc.summary"          ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o B14_5.s.bam                                    ||
# ||                                                                            ||
# ||             Output file : B14_5_fc                                         ||
# ||                 Summary : B14_5_fc.summary                                 ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file B14_5.s.bam...                                            ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 457464                                               ||
# ||    Successfully assigned alignments : 346395 (75.7%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "B14_5_fc.summary"        ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o C15_5.s.bam                                    ||
# ||                                                                            ||
# ||             Output file : C15_5_fc                                         ||
# ||                 Summary : C15_5_fc.summary                                 ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file C15_5.s.bam...                                            ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 385610                                               ||
# ||    Successfully assigned alignments : 290437 (75.3%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "C15_5_fc.summary"        ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o C17_5.s.bam                                    ||
# ||                                                                            ||
# ||             Output file : C17_5_fc                                         ||
# ||                 Summary : C17_5_fc.summary                                 ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file C17_5.s.bam...                                            ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 430213                                               ||
# ||    Successfully assigned alignments : 341855 (79.5%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "C17_5_fc.summary"        ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o B17_5.s.bam                                    ||
# ||                                                                            ||
# ||             Output file : B17_5_fc                                         ||
# ||                 Summary : B17_5_fc.summary                                 ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file B17_5.s.bam...                                            ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 377016                                               ||
# ||    Successfully assigned alignments : 285312 (75.7%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "B17_5_fc.summary"        ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o C34.s.bam                                      ||
# ||                                                                            ||
# ||             Output file : C34_fc                                           ||
# ||                 Summary : C34_fc.summary                                   ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file C34.s.bam...                                              ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 382353                                               ||
# ||    Successfully assigned alignments : 297754 (77.9%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "C34_fc.summary"          ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o B20.s.bam                                      ||
# ||                                                                            ||
# ||             Output file : B20_fc                                           ||
# ||                 Summary : B20_fc.summary                                   ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file B20.s.bam...                                              ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 417945                                               ||
# ||    Successfully assigned alignments : 316238 (75.7%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "B20_fc.summary"          ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o B15_5.s.bam                                    ||
# ||                                                                            ||
# ||             Output file : B15_5_fc                                         ||
# ||                 Summary : B15_5_fc.summary                                 ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file B15_5.s.bam...                                            ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 388382                                               ||
# ||    Successfully assigned alignments : 291980 (75.2%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "B15_5_fc.summary"        ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           o C20.s.bam                                      ||
# ||                                                                            ||
# ||             Output file : C20_fc                                           ||
# ||                 Summary : C20_fc.summary                                   ||
# ||              Annotation : Mus_musculus.GRCm39.107.gtf (GTF)                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Mus_musculus.GRCm39.107.gtf ...                       ||
# ||    Features : 869027                                                       ||
# ||    Meta-features : 56748                                                   ||
# ||    Chromosomes/contigs : 39                                                ||
# ||                                                                            ||
# || Process BAM file C20.s.bam...                                              ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 436469                                               ||
# ||    Successfully assigned alignments : 339815 (77.9%)                       ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "C20_fc.summary"          ||
# ||                                                                            ||
# \\============================================================================//

# %%
! head /content/B14_5_fc
# Out:
# # Program:featureCounts v2.0.1; Command:"featureCounts" "-a" "/content/Mus_musculus.GRCm39.107.gtf" "-o" "B14_5_fc" "B14_5.s.bam"
# Geneid	Chr	Start	End	Strand	Length	B14_5.s.bam
# ENSMUSG00000102628	1	150956201	150958296	+	2096	0
# ENSMUSG00000100595	1	150983666	150984611	+	946	0
# ENSMUSG00000097426	1;1	151012258;151013347	151012971;151013531	+;+	899	0
# ENSMUSG00000104478	1	108344807	108347562	+	2756	0
# ENSMUSG00000104385	1	6980784	6981446	+	663	0
# ENSMUSG00000086053	1;1	75368775;75372851	75369089;75373007	-;-	472	0
# ENSMUSG00000101231	1	108540067	108540244	-	178	0
# ENSMUSG00000102135	1;1	6986783;6993624	6987219;6993812	+;+	626	0
